# %%
#RandomForestClassifier algorithm
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
column_names = [
    "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
    "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"
]

df = pd.read_csv(url, names = column_names, na_values = "?" )
display(df)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
#Drop rows with missing values
df = df.dropna()

# %%
#Feature(column) selection for X (input columns) and y (target variable to be predicted)
X_heart = df.drop('target', axis = 1)
y_heart = df['target']

# %%
#Split the data into training and testing set
X_train_heart, X_test_heart, y_train_heart, y_test_heart = train_test_split(X_heart, y_heart, test_size = 0.2, random_state = 42 )

# %%
#Initializing the RandomForestClassifier algorithm
rf_model_heart = RandomForestClassifier(n_estimators = 100, random_state = 42)

# %%
#Training the model
rf_model_heart.fit(X_train_heart, y_train_heart)
#Testing the model
y_pred_heart = rf_model_heart.predict(X_test_heart)

# %%
accuracy_heart = accuracy_score(y_test_heart, y_pred_heart)
print("Heart Disease Dataset - Random Forest Model Accuracy:", accuracy_heart)
print("Classification Report:")
print(classification_report(y_test_heart, y_pred_heart))
# Out:
# Heart Disease Dataset - Random Forest Model Accuracy: 0.6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88        36
#            1       0.00      0.00      0.00         9
#            2       0.14      0.20      0.17         5
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.19      0.23      0.21        60
# weighted avg       0.49      0.60      0.54        60
